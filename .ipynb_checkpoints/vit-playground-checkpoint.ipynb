# %%
# !pip install linformer
# Out:
# Collecting linformer
#   Downloading linformer-0.2.1-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: torch in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from linformer) (2.0.0)
# Requirement already satisfied: triton==2.0.0 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (2.0.0)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.7.91)
# Requirement already satisfied: filelock in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (3.10.7)
# Requirement already satisfied: networkx in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (3.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (10.9.0.58)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (2.14.3)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.7.4.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.7.99)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.4.0.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.7.101)
# Requirement already satisfied: typing-extensions in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (4.5.0)
# Requirement already satisfied: jinja2 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (3.1.2)
# Requirement already satisfied: sympy in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (1.11.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.10.3.66)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from torch->linformer) (11.7.99)
# Requirement already satisfied: wheel in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->linformer) (0.37.1)
# Requirement already satisfied: setuptools in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->linformer) (65.6.3)
# Requirement already satisfied: cmake in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from triton==2.0.0->torch->linformer) (3.26.1)
# Requirement already satisfied: lit in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from triton==2.0.0->torch->linformer) (16.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from jinja2->torch->linformer) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /work/08823/msrodlab/miniconda3/lib/python3.9/site-packages (from sympy->torch->linformer) (1.3.0)
# Installing collected packages: linformer
# Successfully installed linformer-0.2.1

# %%
from __future__ import print_function

import glob
from itertools import chain
import os
import random
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from linformer import Linformer
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm

from vit_pytorch.efficient import ViT
from datasets import load_dataset

# %%
# !rm -rf home1/08823/msrodlab/.cache/huggingface/datasets/json
dataset = load_dataset("json", data_files={'train': 'train-metadata.jsonl', 'test': 'test-metadata.jsonl'})
# Out:
# Found cached dataset json (/home1/08823/msrodlab/.cache/huggingface/datasets/json/default-e4507dd3f6d3ed03/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
print(train_dataset)
# Out:
# Dataset({
#     features: ['uniqueId', 'image', 'ttf_path', 'font_characteristics', 'character', 'font_properties'],
#     num_rows: 12152
# })

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))

for idx, ax in enumerate(axes.ravel()):
    r_idx = np.random.randint(len(train_dataset), size=(1,))
    ex = train_dataset[r_idx]
    print(ex['font_characteristics'])
    img = Image.open(ex['image'][0])
    ax.set_title(ex['character'][0])
    ax.imshow(img)
# Out:
# ['tall scary graveyard']
# ['childlike school']
# ['thin extremities']
# ['robot modern android']
# ['luxurious fancy modern metropolitan']
# ['bubbly childlike']
# ['plain bent']
# ['winter holiday']
# ['charming uncomplicated comic']

# %%
efficient_transformer = Linformer(
    dim=128,
    seq_len=49+1,  # 7x7 patches + 1 cls-token
    depth=12,
    heads=8,
    k=64
)
device = 'cuda'
model = ViT(
    dim=128,
    image_size=224,
    patch_size=32,
    num_classes=2,
    transformer=efficient_transformer,
    channels=3,
).to(device)

# %%
train_loader = DataLoader(dataset = train_dataset, batch_size=batch_size, shuffle=True )
valid_loader = DataLoader(dataset = test_dataset, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(dataset = test_data, batch_size=batch_size, shuffle=True)
# Out:
# rm: cannot remove ‘/home1/08823/msrodlab/.cache/huggingface/datasets/json/default-13b631bc655bda2c/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e’: Directory not empty

# %%
for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )
